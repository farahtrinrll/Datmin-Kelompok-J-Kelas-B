# %% [markdown]
# <a href="https://colab.research.google.com/github/farahtrinrll/Datmin-Kelompok-J-Kelas-B/blob/main/Data_Mining_Kelompok_J_Study_Case_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Loading Data:
import pandas as pd

try: # Running Locally, yakinkan "file_" berada di folder "data"
    dfJ = pd.read_csv("data/jakarta.csv", low_memory = False, encoding='utf8')
    dfD = pd.read_csv("data/depok.csv", low_memory = False, encoding='utf8')
    dfB = pd.read_csv("data/bogor.csv", low_memory = False, encoding='utf8')
    dfT = pd.read_csv("data/tangerang.csv", low_memory = False, encoding='utf8')
    dfX = pd.read_csv("data/bekasi.csv", low_memory = False, encoding='utf8')    
except: # Running in Google Colab
    # !mkdir data
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/jakarta.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/depok.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/bogor.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/tangerang.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/bekasi.csv
    dfJ = pd.read_csv("data/jakarta.csv", low_memory = False, encoding='utf8')
    dfD = pd.read_csv("data/depok.csv", low_memory = False, encoding='utf8')
    dfB = pd.read_csv("data/bogor.csv", low_memory = False, encoding='utf8')
    dfT = pd.read_csv("data/tangerang.csv", low_memory = False, encoding='utf8')
    dfX = pd.read_csv("data/bekasi.csv", low_memory = False, encoding='utf8')
    
dfJ.shape, dfD.shape, dfB.shape, dfT.shape, dfX.shape
# Out:
# --2022-09-23 06:22:24--  https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/jakarta.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63832 (62K) [text/plain]
# Saving to: ‘data/jakarta.csv’
#
# jakarta.csv         100%[===================>]  62.34K  --.-KB/s    in 0.02s
#
# 2022-09-23 06:22:24 (4.04 MB/s) - ‘data/jakarta.csv’ saved [63832/63832]
#
# --2022-09-23 06:22:24--  https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/depok.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 43191 (42K) [text/plain]
# Saving to: ‘data/depok.csv’
#
# depok.csv           100%[===================>]  42.18K  --.-KB/s    in 0.01s
#
# 2022-09-23 06:22:24 (3.21 MB/s) - ‘data/depok.csv’ saved [43191/43191]
#
# --2022-09-23 06:22:24--  https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/bogor.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68006 (66K) [text/plain]
# Saving to: ‘data/bogor.csv’
#
# bogor.csv           100%[===================>]  66.41K  --.-KB/s    in 0.02s
#
# 2022-09-23 06:22:24 (4.25 MB/s) - ‘data/bogor.csv’ saved [68006/68006]
#
# --2022-09-23 06:22:24--  https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/tangerang.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46485 (45K) [text/plain]
# Saving to: ‘data/tangerang.csv’
#
# tangerang.csv       100%[===================>]  45.40K  --.-KB/s    in 0.01s
#
# 2022-09-23 06:22:24 (3.44 MB/s) - ‘data/tangerang.csv’ saved [46485/46485]
#
# --2022-09-23 06:22:24--  https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/bekasi.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71038 (69K) [text/plain]
# Saving to: ‘data/bekasi.csv’
#
# bekasi.csv          100%[===================>]  69.37K  --.-KB/s    in 0.02s
#
# 2022-09-23 06:22:25 (4.31 MB/s) - ‘data/bekasi.csv’ saved [71038/71038]
# ((1024, 26), (998, 26), (999, 26), (128, 26), (992, 26))

# %%
dfJ
# Out:
#       created_at     LT     LB   KT   KM  garasi  carport         lokasi  \
# 0     06-12-2021  202.0  198.0  8.0  3.0     NaN      NaN  Jakarta Pusat
# 1     02-12-2021   30.0   55.0  2.0  1.0     NaN      1.0  Jakarta Pusat
# 2     06-12-2021   19.0   35.0  2.0  1.0     NaN      NaN  Jakarta Pusat
# 3     06-12-2021   33.0   42.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# 4     06-12-2021   30.0   55.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# ...          ...    ...    ...  ...  ...     ...      ...            ...
# 1019         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 1020         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 1021         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 1022         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 1023         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
#
#      sertifikat  listrik  ... Unnamed: 16  Unnamed: 17 Unnamed: 18  \
# 0           SHM   2200.0  ...         NaN          NaN         NaN
# 1           SHM   2200.0  ...         NaN          NaN         NaN
# 2           SHM   2200.0  ...         NaN          NaN         NaN
# 3           SHM   2200.0  ...         NaN          NaN         NaN
# 4           SHM   2200.0  ...         NaN          NaN         NaN
# ...         ...      ...  ...         ...          ...         ...
# 1019        NaN      NaN  ...         NaN          NaN         NaN
# 1020        NaN      NaN  ...         NaN          NaN         NaN
# 1021        NaN      NaN  ...         NaN          NaN         NaN
# 1022        NaN      NaN  ...         NaN          NaN         NaN
# 1023        NaN      NaN  ...         NaN          NaN         NaN
#
#      Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ...          ...          ...          ...          ...          ...
# 1019         NaN          NaN          NaN          NaN          NaN
# 1020         NaN          NaN          NaN          NaN          NaN
# 1021         NaN          NaN          NaN          NaN          NaN
# 1022         NaN          NaN          NaN          NaN          NaN
# 1023         NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 24  Unnamed: 25
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ...           ...          ...
# 1019          NaN          NaN
# 1020          NaN          NaN
# 1021          NaN          NaN
# 1022          NaN          NaN
# 1023          NaN          NaN
#
# [1024 rows x 26 columns]

# %%
dfD
# Out:
#     created_at   LT     LB   KT   KM  garasi  carport     lokasi sertifikat  \
# 0    6-12-2021  165  200.0  4.0  2.0     NaN      1.0  Sukmajaya        SHM
# 1    6-12-2021   50   45.0  2.0  1.0     NaN      NaN   Cipayung        SHM
# 2    6-12-2021   50   36.0  2.0  1.0     NaN      1.0   Sawangan        SHM
# 3    6-12-2021   50   45.0  2.0  1.0     NaN      NaN  Cimanggis        SHM
# 4    6-12-2021   72   45.0  2.0  1.0     NaN      1.0   Sawangan        SHM
# ..         ...  ...    ...  ...  ...     ...      ...        ...        ...
# 993        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
# 994        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
# 995        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
# 996        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
# 997        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
#
#      listrik  ... Unnamed: 16  Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0     2200.0  ...         NaN          NaN         NaN         NaN
# 1     1300.0  ...         NaN          NaN         NaN         NaN
# 2     1300.0  ...         NaN          NaN         NaN         NaN
# 3     1300.0  ...         NaN          NaN         NaN         NaN
# 4     1300.0  ...         NaN          NaN         NaN         NaN
# ..       ...  ...         ...          ...         ...         ...
# 993      NaN  ...         NaN          NaN         NaN         NaN
# 994      NaN  ...         NaN          NaN         NaN         NaN
# 995      NaN  ...         NaN          NaN         NaN         NaN
# 996      NaN  ...         NaN          NaN         NaN         NaN
# 997      NaN  ...         NaN          NaN         NaN         NaN
#
#      Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 993          NaN          NaN          NaN          NaN          NaN
# 994          NaN          NaN          NaN          NaN          NaN
# 995          NaN          NaN          NaN          NaN          NaN
# 996          NaN          NaN          NaN          NaN          NaN
# 997          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 25
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 993          NaN
# 994          NaN
# 995          NaN
# 996          NaN
# 997          NaN
#
# [998 rows x 26 columns]

# %%
dfB
# Out:
#      created_at    LT    LB   KT   KM  garasi  carport          lokasi  \
# 0    03-12-2021  75.0  38.0  2.0  1.0     1.0      1.0      Bojonggede
# 1    06-12-2021  60.0  40.0  1.0  1.0     0.0      1.0  Babakan Madang
# 2    06-12-2021  60.0  50.0  2.0  2.0     0.0      1.0  Babakan Madang
# 3    06-12-2021  60.0  70.0  3.0  2.0     0.0      1.0  Babakan Madang
# 4    06-12-2021  90.0  60.0  3.0  2.0     0.0      2.0  Babakan Madang
# ..          ...   ...   ...  ...  ...     ...      ...             ...
# 994         NaN   NaN   NaN  NaN  NaN     NaN      NaN             NaN
# 995         NaN   NaN   NaN  NaN  NaN     NaN      NaN             NaN
# 996         NaN   NaN   NaN  NaN  NaN     NaN      NaN             NaN
# 997         NaN   NaN   NaN  NaN  NaN     NaN      NaN             NaN
# 998         NaN   NaN   NaN  NaN  NaN     NaN      NaN             NaN
#
#     sertifikat  listrik  ... Unnamed: 16  Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0          SHM   1300.0  ...         NaN          NaN         NaN         NaN
# 1          SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 2          SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 3          SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 4          SHM   2200.0  ...         NaN          NaN         NaN         NaN
# ..         ...      ...  ...         ...          ...         ...         ...
# 994        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 995        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 996        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 997        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 998        NaN      NaN  ...         NaN          NaN         NaN         NaN
#
#      Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 994          NaN          NaN          NaN          NaN          NaN
# 995          NaN          NaN          NaN          NaN          NaN
# 996          NaN          NaN          NaN          NaN          NaN
# 997          NaN          NaN          NaN          NaN          NaN
# 998          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 25
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 994          NaN
# 995          NaN
# 996          NaN
# 997          NaN
# 998          NaN
#
# [999 rows x 26 columns]

# %%
dfT
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport  \
# 0    12-06-2021   60.0   50.0  3.0  2.0     NaN      NaN
# 1    12-06-2021   72.0   54.0  2.0  1.0     1.0      1.0
# 2    12-06-2021   60.0   48.0  3.0  2.0     2.0      2.0
# 3    12-06-2021  200.0  225.0  5.0  4.0     NaN      NaN
# 4    12-06-2021   76.0  123.0  3.0  3.0     NaN      2.0
# ..          ...    ...    ...  ...  ...     ...      ...
# 123  12-08-2021   91.0   91.0  3.0  2.0     NaN      NaN
# 124         NaN    NaN    NaN  NaN  NaN     NaN      NaN
# 125         NaN    NaN    NaN  NaN  NaN     NaN      NaN
# 126         NaN    NaN    NaN  NaN  NaN     NaN      NaN
# 127         NaN    NaN    NaN  NaN  NaN     NaN      NaN
#
#                         lokasi sertifikat  listrik  ... Unnamed: 16  \
# 0          BSD CITY, TANGERANG        SHM   1300.0  ...         NaN
# 1            CISAUK, TANGERANG        SHM   1300.0  ...         NaN
# 2           CILEDUG, TANGERANG        SHM   2200.0  ...         NaN
# 3    LIPPO KARAWACI, TANGERANG        SHM   5500.0  ...         NaN
# 4       PONDOK CABE, TANGERANG        SHM   2200.0  ...         NaN
# ..                         ...        ...      ...  ...         ...
# 123           Poris, Tangerang        SHM   3500.0  ...         NaN
# 124                        NaN        NaN      NaN  ...         NaN
# 125                        NaN        NaN      NaN  ...         NaN
# 126                        NaN        NaN      NaN  ...         NaN
# 127                        NaN        NaN      NaN  ...         NaN
#
#      Unnamed: 17 Unnamed: 18 Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 0            NaN         NaN         NaN          NaN          NaN
# 1            NaN         NaN         NaN          NaN          NaN
# 2            NaN         NaN         NaN          NaN          NaN
# 3            NaN         NaN         NaN          NaN          NaN
# 4            NaN         NaN         NaN          NaN          NaN
# ..           ...         ...         ...          ...          ...
# 123          NaN         NaN         NaN          NaN          NaN
# 124          NaN         NaN         NaN          NaN          NaN
# 125          NaN         NaN         NaN          NaN          NaN
# 126          NaN         NaN         NaN          NaN          NaN
# 127          NaN         NaN         NaN          NaN          NaN
#
#      Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 0            NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...
# 123          NaN          NaN          NaN          NaN
# 124          NaN          NaN          NaN          NaN
# 125          NaN          NaN          NaN          NaN
# 126          NaN          NaN          NaN          NaN
# 127          NaN          NaN          NaN          NaN
#
# [128 rows x 26 columns]

# %%
dfX
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport            lokasi  \
# 0    08-12-2021   71.0   43.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi
# 1    08-12-2021   59.0   60.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi
# 2    08-12-2021  124.0   95.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi
# 3    08-12-2021  144.0  100.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi
# 4    08-12-2021  108.0  100.0  3.0  2.0     NaN      1.0  Kabupaten Bekasi
# ..          ...    ...    ...  ...  ...     ...      ...               ...
# 987         NaN    NaN    NaN  NaN  NaN     NaN      NaN               NaN
# 988         NaN    NaN    NaN  NaN  NaN     NaN      NaN               NaN
# 989         NaN    NaN    NaN  NaN  NaN     NaN      NaN               NaN
# 990         NaN    NaN    NaN  NaN  NaN     NaN      NaN               NaN
# 991         NaN    NaN    NaN  NaN  NaN     NaN      NaN               NaN
#
#     sertifikat  listrik  ... Unnamed: 16  Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0          SHM   1300.0  ...         NaN          NaN         NaN         NaN
# 1          SHM      NaN  ...         NaN          NaN         NaN         NaN
# 2          SHM      NaN  ...         NaN          NaN         NaN         NaN
# 3          SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 4          SHM   2200.0  ...         NaN          NaN         NaN         NaN
# ..         ...      ...  ...         ...          ...         ...         ...
# 987        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 988        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 989        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 990        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 991        NaN      NaN  ...         NaN          NaN         NaN         NaN
#
#      Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 987          NaN          NaN          NaN          NaN          NaN
# 988          NaN          NaN          NaN          NaN          NaN
# 989          NaN          NaN          NaN          NaN          NaN
# 990          NaN          NaN          NaN          NaN          NaN
# 991          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 25
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 987          NaN
# 988          NaN
# 989          NaN
# 990          NaN
# 991          NaN
#
# [992 rows x 26 columns]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas import read_csv

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas import read_csv
dfX
dfX.shape
dfX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992 entries, 0 to 991
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   created_at   107 non-null    object
#  1   LT           107 non-null    float64
#  2   LB           107 non-null    float64
#  3   KT           107 non-null    float64
#  4   KM           106 non-null    float64
#  5   garasi       33 non-null     float64
#  6   carport      81 non-null     float64
#  7   lokasi       107 non-null    object
#  8   sertifikat   106 non-null    object
#  9   listrik      101 non-null    float64
#  10  hadap        48 non-null     object
#  11  harga        107 non-null    float64
#  12  URL          107 non-null    object
#  13  deskripsi    107 non-null    object
#  14  Unnamed: 14  0 non-null      float64
#  15  Unnamed: 15  0 non-null      float64
#  16  Unnamed: 16  0 non-null      float64
#  17  Unnamed: 17  0 non-null      float64
#  18  Unnamed: 18  0 non-null      float64
#  19  Unnamed: 19  0 non-null      float64
#  20  Unnamed: 20  0 non-null      float64
#  21  Unnamed: 21  0 non-null      float64
#  22  Unnamed: 22  0 non-null      float64
#  23  Unnamed: 23  0 non-null      float64
#  24  Unnamed: 24  0 non-null      float64
#  25  Unnamed: 25  0 non-null      float64
# dtypes: float64(20), object(6)
# memory usage: 201.6+ KB

# %%
dfX.drop(dfX.columns[14:26], axis=1, inplace=True)
print(dfX)
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport            lokasi  \
# 0    08-12-2021   71.0   43.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi
# 1    08-12-2021   59.0   60.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi
# 2    08-12-2021  124.0   95.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi
# 3    08-12-2021  144.0  100.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi
# 4    08-12-2021  108.0  100.0  3.0  2.0     NaN      1.0  Kabupaten Bekasi
# ..          ...    ...    ...  ...  ...     ...      ...               ...
# 987         NaN    NaN    NaN  NaN  NaN     NaN      NaN               NaN
# 988         NaN    NaN    NaN  NaN  NaN     NaN      NaN               NaN
# 989         NaN    NaN    NaN  NaN  NaN     NaN      NaN               NaN
# 990         NaN    NaN    NaN  NaN  NaN     NaN      NaN               NaN
# 991         NaN    NaN    NaN  NaN  NaN     NaN      NaN               NaN
#
#     sertifikat  listrik    hadap         harga  \
# 0          SHM   1300.0      NaN  5.500000e+08
# 1          SHM      NaN      NaN  4.400000e+08
# 2          SHM      NaN      NaN  6.990000e+08
# 3          SHM   2200.0  Selatan  1.350000e+09
# 4          SHM   2200.0    Timur  1.400000e+09
# ..         ...      ...      ...           ...
# 987        NaN      NaN      NaN           NaN
# 988        NaN      NaN      NaN           NaN
# 989        NaN      NaN      NaN           NaN
# 990        NaN      NaN      NaN           NaN
# 991        NaN      NaN      NaN           NaN
#
#                                                    URL  \
# 0    Rumah murah di metland cibitung bekasi - Dijua...
# 1    Rumah dijual di Griya gandasari cibitung - Dij...
# 2    Jual cepat rumah huuk di metland cibitung beka...
# 3    https://www.realoka.com/216243-rumah-rapi-siap...
# 4    https://www.realoka.com/207964-jual-rumah-bagu...
# ..                                                 ...
# 987                                                NaN
# 988                                                NaN
# 989                                                NaN
# 990                                                NaN
# 991                                                NaN
#
#                                              deskripsi
# 0    Selangkah ke stasiun krl telaga murni, Dekat d...
# 1    Rumah sangat nyaman,dan terbukti bebas banjir,...
# 2    Bebas banjir, Carport dan tanah luas ada taman...
# 3    (Harapan Indah) Cluster Aralia Kota Harapan In...
# 4    (Harapan Indah) Cluster Harmoni Perumahan Kota...
# ..                                                 ...
# 987                                                NaN
# 988                                                NaN
# 989                                                NaN
# 990                                                NaN
# 991                                                NaN
#
# [992 rows x 14 columns]

# %%
dfX.duplicated().sum()
# Out:
# 884

# %%
dfX.duplicated().sum()
dfX.describe()
# Out:
#                LT          LB          KT          KM     garasi    carport  \
# count  107.000000  107.000000  107.000000  106.000000  33.000000  81.000000
# mean   108.822430  110.635514    2.962617    1.943396   1.090909   1.086420
# std     59.164914   71.755270    1.027226    0.848867   0.291937   0.282734
# min     36.000000   30.000000    1.000000    1.000000   1.000000   1.000000
# 25%     72.000000   60.000000    2.000000    1.000000   1.000000   1.000000
# 50%     91.000000   90.000000    3.000000    2.000000   1.000000   1.000000
# 75%    130.500000  144.000000    4.000000    2.750000   1.000000   1.000000
# max    364.000000  494.000000    7.000000    4.000000   2.000000   2.000000
#
#            listrik         harga
# count   101.000000  1.070000e+02
# mean   2056.435644  1.074823e+09
# std     969.578861  7.516152e+08
# min     900.000000  1.600000e+08
# 25%    1300.000000  5.805000e+08
# 50%    2200.000000  9.200000e+08
# 75%    2200.000000  1.350000e+09
# max    5500.000000  4.500000e+09

# %%
dfX.head()
# Out:
#    created_at     LT     LB   KT   KM  garasi  carport            lokasi  \
# 0  08-12-2021   71.0   43.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi
# 1  08-12-2021   59.0   60.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi
# 2  08-12-2021  124.0   95.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi
# 3  08-12-2021  144.0  100.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi
# 4  08-12-2021  108.0  100.0  3.0  2.0     NaN      1.0  Kabupaten Bekasi
#
#   sertifikat  listrik    hadap         harga  \
# 0        SHM   1300.0      NaN  5.500000e+08
# 1        SHM      NaN      NaN  4.400000e+08
# 2        SHM      NaN      NaN  6.990000e+08
# 3        SHM   2200.0  Selatan  1.350000e+09
# 4        SHM   2200.0    Timur  1.400000e+09
#
#                                                  URL  \
# 0  Rumah murah di metland cibitung bekasi - Dijua...
# 1  Rumah dijual di Griya gandasari cibitung - Dij...
# 2  Jual cepat rumah huuk di metland cibitung beka...
# 3  https://www.realoka.com/216243-rumah-rapi-siap...
# 4  https://www.realoka.com/207964-jual-rumah-bagu...
#
#                                            deskripsi
# 0  Selangkah ke stasiun krl telaga murni, Dekat d...
# 1  Rumah sangat nyaman,dan terbukti bebas banjir,...
# 2  Bebas banjir, Carport dan tanah luas ada taman...
# 3  (Harapan Indah) Cluster Aralia Kota Harapan In...
# 4  (Harapan Indah) Cluster Harmoni Perumahan Kota...

# %%
dfX.corr()
# Out:
#                LT        LB        KT        KM    garasi   carport   listrik  \
# LT       1.000000  0.789951  0.526416  0.475517 -0.044791  0.232852  0.612727
# LB       0.789951  1.000000  0.662415  0.701031  0.050786  0.215932  0.593433
# KT       0.526416  0.662415  1.000000  0.649954  0.088182  0.126119  0.565145
# KM       0.475517  0.701031  0.649954  1.000000  0.073979  0.212385  0.616469
# garasi  -0.044791  0.050786  0.088182  0.073979  1.000000  0.625000  0.129986
# carport  0.232852  0.215932  0.126119  0.212385  0.625000  1.000000  0.223318
# listrik  0.612727  0.593433  0.565145  0.616469  0.129986  0.223318  1.000000
# harga    0.777926  0.711167  0.596517  0.649860 -0.053740  0.171206  0.734153
#
#             harga
# LT       0.777926
# LB       0.711167
# KT       0.596517
# KM       0.649860
# garasi  -0.053740
# carport  0.171206
# listrik  0.734153
# harga    1.000000

# %%
#melihat adanya outlier
p = sns.boxplot(x="LT", y="harga", data=dfX)

# %%
#melihat adanya outlier
p = sns.boxplot(x="LT", y="harga", data=dfX)
#mengecek apakah terdapat duplikasi data
print(dfX.shape)
dfX.duplicated().sum()
#terlihat jumlah duplikasi data adalah 1
# Out:
# (992, 14)
# 884

# %%
#menghapus data duplikat
dfX.drop_duplicates(inplace=True)
print(dfX.duplicated().sum())
print(dfX.shape)
# Out:
# 0
# (108, 14)

# %%
#mengecek jumlah missing value
print(dfX.isnull().sum())
#Terlihat banyak missing value
# Out:
# created_at     1
# LT             1
# LB             1
# KT             1
# KM             2
# garasi        75
# carport       27
# lokasi         1
# sertifikat     2
# listrik        7
# hadap         60
# harga          1
# URL            1
# deskripsi      1
# dtype: int64

# %%
#cek apakah pria atau wanita ada kecenderungan memberi tips lebih besar
p= sns.catplot(x="hadap", y="harga", hue="garasi", kind="box", data=dfX)

# %%
#untuk mengetahui harga terbesar terdapat di lokasi mana
besar_harga=dfX.groupby('lokasi')['harga'].sum().reset_index()
besar_harga
# Out:
#              lokasi         harga
# 0  Kabupaten Bekasi  2.621615e+10
# 1       Kota Bekasi  8.878995e+10

# %%
#untuk mengetahui  di tiap harinya
sns.countplot(x="sex", hue="day", palette="muted", data=tips)

# %% [markdown]
# 1. Kualitas data perusahaan
# Berdasarkan dataset Bekasi, dilihat dari

# %%
dfX.dropna(axis=0)
# Out:
#     created_at     LT     LB   KT   KM  garasi  carport            lokasi  \
# 17  06-12-2021  200.0  250.0  4.0  3.0     1.0      1.0       Kota Bekasi
# 18  06-12-2021   60.0   55.0  2.0  1.0     1.0      1.0       Kota Bekasi
# 24  06-12-2021   60.0   40.0  2.0  1.0     1.0      1.0       Kota Bekasi
# 33  06-12-2021  200.0  250.0  4.0  3.0     1.0      1.0       Kota Bekasi
# 38  06-12-2021   54.0   84.0  2.0  1.0     1.0      1.0  Kabupaten Bekasi
# 39  05-12-2021   90.0   80.0  2.0  1.0     1.0      1.0       Kota Bekasi
# 46  05-12-2021  112.0  120.0  3.0  2.0     1.0      1.0  Kabupaten Bekasi
# 49  05-12-2021  100.0  112.0  2.0  2.0     1.0      1.0       Kota Bekasi
# 52  05-12-2021  101.0   90.0  3.0  3.0     1.0      1.0       Kota Bekasi
# 53  05-12-2021  100.0  112.0  2.0  2.0     1.0      1.0       Kota Bekasi
# 61  04-12-2021   84.0  180.0  4.0  3.0     2.0      2.0       Kota Bekasi
# 65  04-12-2021   60.0   32.0  2.0  1.0     1.0      1.0  Kabupaten Bekasi
# 71  04-12-2021  160.0   70.0  3.0  1.0     1.0      1.0  Kabupaten Bekasi
# 90  02-12-2021  135.0  110.0  3.0  3.0     1.0      1.0       Kota Bekasi
# 91  02-12-2021   60.0   60.0  2.0  2.0     1.0      1.0  Kabupaten Bekasi
# 94  02-12-2021  105.0  130.0  3.0  3.0     1.0      1.0       Kota Bekasi
#
#    sertifikat  listrik    hadap         harga  \
# 17        SHM   2200.0  Selatan  2.300000e+09
# 18        SHM   1300.0    Barat  6.000000e+08
# 24        SHM   1300.0    Timur  3.750000e+08
# 33        SHM   2200.0  Selatan  2.300000e+09
# 38        SHM   1300.0    Timur  6.500000e+08
# 39        SHM   2200.0  Selatan  8.900000e+08
# 46        SHM   2200.0  Selatan  1.100000e+09
# 49        SHM   1300.0  Selatan  7.500000e+08
# 52        SHM   2200.0  Selatan  1.600000e+09
# 53        SHM   1300.0  Selatan  7.500000e+08
# 61        SHM   2200.0    Utara  1.350000e+09
# 65        SHM   1300.0    Timur  4.810000e+08
# 71        SHM    900.0  Selatan  9.250000e+08
# 90        SHM   2200.0  Selatan  1.200000e+09
# 91        SHM   1300.0  Selatan  3.990000e+08
# 94        SHM   2200.0  Selatan  1.200000e+09
#
#                                                   URL  \
# 17  https://www.rumah123.com/properti/bekasi/hos92...
# 18  https://www.rumah123.com/properti/bekasi/hos92...
# 24  https://www.rumah123.com/properti/bekasi/hos92...
# 33  https://www.rumah123.com/properti/bekasi/hos92...
# 38  https://www.rumah123.com/properti/bogor/hos929...
# 39  https://www.rumah123.com/properti/bekasi/hos92...
# 46  https://www.rumah123.com/properti/bekasi/hos92...
# 49  https://www.rumah123.com/properti/bekasi/hos92...
# 52                   https://rumahdijual.com/11635978
# 53  Rumah Cantik Siap Huni Tanah Luas Akses 2 Mobi...
# 61  https://www.rumah123.com/properti/bekasi/hos92...
# 65  https://www.rumah123.com/properti/bekasi/hos92...
# 71  https://www.rumah123.com/properti/bekasi/hos92...
# 90  https://www.rumah123.com/properti/bekasi/hos92...
# 91  https://www.rumah123.com/properti/bekasi/hos92...
# 94  https://www.rumah123.com/properti/bekasi/hos92...
#
#                                             deskripsi
# 17  rumah mewah dalam cluster eksklusif di harapan...
# 18  Dijual Rumah Pesona Anggrek Harapan Bekasi Uta...
# 24  Dekat jalan raya, Dekat fasilitas umum seperti...
# 33  Dijual cepat harga BU !!, rumah mewah dalam cl...
# 38  terletak dalam 2 wilayah berdekatan kabupaten ...
# 39  Lokasi strategis aman asri tenang, security 24...
# 46  Dijual rumah 2 lantai siap huni dalam cluster ...
# 49  Lingkungan perumahan komplek, lokasi strategis...
# 52  Luas Tanah 101m2 (6,5x7), luas Bangunan 90m2, ...
# 53  Rumah Di Dukuh Zamrud Mustika Jaya, Bekasi kot...
# 61  Perumahan TYTYAN KENCANA Lokasi dikawasan yg s...
# 65  Smart Home Sistem: Smart Door Lock, CCTV, Fasi...
# 71  Dalam komplek yg nyaman, jalan 2 mbl, butuh re...
# 90  Di Jual Rumah Murah di Jaka sampurna Bekasi ,l...
# 91  Lokasi Perumahan sangat Strategis dan hidup., ...
# 94  Dijual cepat Rumah cantik rapih siap huni di b...

# %%
dfX.nlargest(1,'harga')
# Out:
#     created_at     LT     LB   KT   KM  garasi  carport       lokasi  \
# 31  06-12-2021  200.0  293.0  6.0  4.0     1.0      1.0  Kota Bekasi
#
#    sertifikat  listrik hadap         harga  \
# 31        SHM   5500.0   NaN  4.500000e+09
#
#                                                   URL  \
# 31  https://www.99.co/id/properti/rumah-mewah-harg...
#
#                                             deskripsi
# 31  Jual cepat rumah mewah harga murah , 3 Lantai,...

# %%
dfX.dtypes
# Out:
# created_at     object
# LT            float64
# LB            float64
# KT            float64
# KM            float64
# garasi        float64
# carport       float64
# lokasi         object
# sertifikat     object
# listrik       float64
# hadap          object
# harga         float64
# URL            object
# deskripsi      object
# dtype: object

# %%
import seaborn as sns
p= sns.catplot(x="LT", y="harga", data=dfX)

# %%
dfJ
dfJ.drop(dfJ.columns[14:26], axis=1, inplace=True)
print(dfJ)
# Out:
#       created_at     LT     LB   KT   KM  garasi  carport         lokasi  \
# 0     06-12-2021  202.0  198.0  8.0  3.0     NaN      NaN  Jakarta Pusat
# 1     02-12-2021   30.0   55.0  2.0  1.0     NaN      1.0  Jakarta Pusat
# 2     06-12-2021   19.0   35.0  2.0  1.0     NaN      NaN  Jakarta Pusat
# 3     06-12-2021   33.0   42.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# 4     06-12-2021   30.0   55.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# ...          ...    ...    ...  ...  ...     ...      ...            ...
# 1019         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 1020         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 1021         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 1022         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 1023         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
#
#      sertifikat  listrik hadap         harga  \
# 0           SHM   2200.0   NaN  4.500000e+09
# 1           SHM   2200.0   NaN  1.100000e+09
# 2           SHM   2200.0   NaN  3.950000e+08
# 3           SHM   2200.0   NaN  8.350000e+08
# 4           SHM   2200.0   NaN  1.100000e+09
# ...         ...      ...   ...           ...
# 1019        NaN      NaN   NaN           NaN
# 1020        NaN      NaN   NaN           NaN
# 1021        NaN      NaN   NaN           NaN
# 1022        NaN      NaN   NaN           NaN
# 1023        NaN      NaN   NaN           NaN
#
#                                                     URL  \
# 0     https://www.rumah.com/listing-properti/dijual-...
# 1     https://www.rumah.com/listing-properti/dijual-...
# 2     https://www.rumah.com/listing-properti/dijual-...
# 3     https://www.rumah.com/listing-properti/dijual-...
# 4     https://www.rumah.com/listing-properti/dijual-...
# ...                                                 ...
# 1019                                                NaN
# 1020                                                NaN
# 1021                                                NaN
# 1022                                                NaN
# 1023                                                NaN
#
#                                               deskripsi
# 0     Dekat Cikini Salemba Taman Isamail Marzuki Kam...
# 1     Mengusung konsep minimalis, dan didukung denga...
# 2     Dekat dengan Mall Atrium Senen, dekat dengan a...
# 3     Berlokasi sangat strategis, sangat dekat ke Tu...
# 4     Bisa request ubah tata ruang, beli 2 unit mend...
# ...                                                 ...
# 1019                                                NaN
# 1020                                                NaN
# 1021                                                NaN
# 1022                                                NaN
# 1023                                                NaN
#
# [1024 rows x 14 columns]

# %%
dfD
dfD.drop(dfD.columns[14:26], axis=1, inplace=True)
print(dfD)
# Out:
#     created_at   LT     LB   KT   KM  garasi  carport     lokasi sertifikat  \
# 0    6-12-2021  165  200.0  4.0  2.0     NaN      1.0  Sukmajaya        SHM
# 1    6-12-2021   50   45.0  2.0  1.0     NaN      NaN   Cipayung        SHM
# 2    6-12-2021   50   36.0  2.0  1.0     NaN      1.0   Sawangan        SHM
# 3    6-12-2021   50   45.0  2.0  1.0     NaN      NaN  Cimanggis        SHM
# 4    6-12-2021   72   45.0  2.0  1.0     NaN      1.0   Sawangan        SHM
# ..         ...  ...    ...  ...  ...     ...      ...        ...        ...
# 993        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
# 994        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
# 995        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
# 996        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
# 997        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
#
#      listrik    hadap   harga  \
# 0     2200.0  Selatan  2100.0
# 1     1300.0      NaN   250.0
# 2     1300.0    Barat   250.0
# 3     1300.0      NaN   250.0
# 4     1300.0    Timur   350.0
# ..       ...      ...     ...
# 993      NaN      NaN     NaN
# 994      NaN      NaN     NaN
# 995      NaN      NaN     NaN
# 996      NaN      NaN     NaN
# 997      NaN      NaN     NaN
#
#                                                    URL  \
# 0    https://www.rumah123.com/properti/depok/hos928...
# 1    https://www.rumah123.com/properti/depok/hos928...
# 2    https://www.rumah123.com/properti/depok/hos928...
# 3    https://www.rumah123.com/properti/depok/hos928...
# 4    https://www.rumah123.com/properti/depok/hos928...
# ..                                                 ...
# 993                                                NaN
# 994                                                NaN
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
#
#                                             deskripsi
# 0                       Rumah siap huni komplek Pelni
# 1                 rumah minimalis termurah di citayam
# 2             CLUSTER TERMURAH DI SAWANGAN KOTA DEPOK
# 3    RUMAH SIAP HUNI HARGA NEGO DEKAT STASIUN CITAYAM
# 4                       Rumah Cluster Siap Huni Depok
# ..                                                ...
# 993                                               NaN
# 994                                               NaN
# 995                                               NaN
# 996                                               NaN
# 997                                               NaN
#
# [998 rows x 14 columns]

# %% [markdown]
# Batas
# -------------

# %%
# Loading Data:
import pandas as pd

try: # Running Locally, yakinkan "file_" berada di folder "data"
    dfJ = pd.read_csv("data/jakarta.csv", low_memory = False, encoding='utf8')
    dfD = pd.read_csv("data/depok.csv", low_memory = False, encoding='utf8')
    dfB = pd.read_csv("data/bogor.csv", low_memory = False, encoding='utf8')
    dfT = pd.read_csv("data/tangerang.csv", low_memory = False, encoding='utf8')
    dfX = pd.read_csv("data/bekasi.csv", low_memory = False, encoding='utf8')    
except: # Running in Google Colab
    # !mkdir data
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/jakarta.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/depok.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/bogor.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/tangerang.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/bekasi.csv
    dfJ = pd.read_csv("data/jakarta.csv", low_memory = False, encoding='utf8')
    dfD = pd.read_csv("data/depok.csv", low_memory = False, encoding='utf8')
    dfB = pd.read_csv("data/bogor.csv", low_memory = False, encoding='utf8')
    dfT = pd.read_csv("data/tangerang.csv", low_memory = False, encoding='utf8')
    dfX = pd.read_csv("data/bekasi.csv", low_memory = False, encoding='utf8')
    
dfJ.shape, dfD.shape, dfB.shape, dfT.shape, dfX.shape
# Out:
# ((1024, 26), (998, 26), (999, 26), (128, 26), (992, 26))

# %%
dfJ["Kota"] = Jakarta
dfJ.drop(dfJ.index[121:1024],inplace=True)
dfJ.tail()
# Out:
#       created_at     LT     LB   KT   KM  garasi  carport         lokasi  \
# 116   22-11-2021  220.0  239.0  5.0  4.0     1.0      2.0  Jakarta Timur
# 117   06-12-2021   70.0   57.0  3.0  2.0     NaN      2.0  Jakarta Timur
# 998          NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 999          NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 1000         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
#
#      sertifikat  listrik  ... Unnamed: 16  Unnamed: 17 Unnamed: 18  \
# 116        PPJB   3500.0  ...         NaN          NaN         NaN
# 117         SHM   2200.0  ...         NaN          NaN         NaN
# 998         NaN      NaN  ...         NaN          NaN         NaN
# 999         NaN      NaN  ...         NaN          NaN         NaN
# 1000        NaN      NaN  ...         NaN          NaN         NaN
#
#      Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 116          NaN          NaN          NaN          NaN          NaN
# 117          NaN          NaN          NaN          NaN          NaN
# 998          NaN          NaN          NaN          NaN          NaN
# 999          NaN          NaN          NaN          NaN          NaN
# 1000         NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 24  Unnamed: 25
# 116           NaN          NaN
# 117           NaN          NaN
# 998           NaN          NaN
# 999           NaN          NaN
# 1000          NaN          NaN
#
# [5 rows x 26 columns]

# %%
dfD.drop(dfD.index[118:998],inplace=True)
dfD.tail()
# Out:
#     created_at   LT     LB   KT   KM  garasi  carport     lokasi sertifikat  \
# 113  4-12-2021   79  115.0  2.0  1.0     1.0      1.0  Sukmajaya        SHM
# 114  4-12-2021   72   45.0  2.0  1.0     NaN      1.0  Cimanggis        SHM
# 115  4-12-2021   40   40.0  2.0  1.0     NaN      NaN   Cipayung        SHM
# 116  4-12-2021   50   50.0  2.0  1.0     NaN      NaN   Cipayung        SHM
# 117  4-12-2021  100   15.0  3.0  3.0     1.0      1.0     Cinere        SHM
#
#      listrik  ... Unnamed: 16  Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 113      NaN  ...         NaN          NaN         NaN         NaN
# 114      NaN  ...         NaN          NaN         NaN         NaN
# 115   1300.0  ...         NaN          NaN         NaN         NaN
# 116   1300.0  ...         NaN          NaN         NaN         NaN
# 117   3500.0  ...         NaN          NaN         NaN         NaN
#
#      Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 113          NaN          NaN          NaN          NaN          NaN
# 114          NaN          NaN          NaN          NaN          NaN
# 115          NaN          NaN          NaN          NaN          NaN
# 116          NaN          NaN          NaN          NaN          NaN
# 117          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 25
# 113          NaN
# 114          NaN
# 115          NaN
# 116          NaN
# 117          NaN
#
# [5 rows x 26 columns]

# %%
dfB.drop(dfB.index[193:999],inplace=True)
dfB.tail()
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport         lokasi  \
# 188  03-12-2021   90.0   36.0  2.0  1.0     0.0      1.0   Gunung Putri
# 189  03-12-2021  107.0   31.0  2.0  1.0     0.0      1.0       Sukaraja
# 190  03-12-2021  210.0  150.0  4.0  2.0     1.0      1.0  Bogor Selatan
# 191  03-12-2021   90.0   36.0  2.0  1.0     0.0      1.0      Cileungsi
# 192  03-12-2021   72.0   90.0  3.0  2.0     1.0      1.0       Cibinong
#
#     sertifikat  listrik  ... Unnamed: 16  Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 188        SHM   1300.0  ...         NaN          NaN         NaN         NaN
# 189        SHM   1300.0  ...         NaN          NaN         NaN         NaN
# 190        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 191        SHM   1300.0  ...         NaN          NaN         NaN         NaN
# 192        SHM   2200.0  ...         NaN          NaN         NaN         NaN
#
#      Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 188          NaN          NaN          NaN          NaN          NaN
# 189          NaN          NaN          NaN          NaN          NaN
# 190          NaN          NaN          NaN          NaN          NaN
# 191          NaN          NaN          NaN          NaN          NaN
# 192          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 25
# 188          NaN
# 189          NaN
# 190          NaN
# 191          NaN
# 192          NaN
#
# [5 rows x 26 columns]

# %%
dfT.drop(dfT.index[124:129],inplace=True)
dfT.tail()
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport  \
# 119  12-08-2021   60.0   55.0  2.0  2.0     NaN      1.0
# 120  12-08-2021   66.0   70.0  3.0  2.0     NaN      1.0
# 121  12-08-2021  202.0   85.0  4.0  3.0     1.0      1.0
# 122  12-08-2021  108.0  130.0  3.0  3.0     1.0      1.0
# 123  12-08-2021   91.0   91.0  3.0  2.0     NaN      NaN
#
#                         lokasi                       sertifikat  listrik  ...  \
# 119  LIPPO KARAWACI, TANGERANG  lainnya(PPJB, GIRIK, ADAT, dll)   2200.0  ...
# 120          Ciater, Tangerang                              SHM   1300.0  ...
# 121  BSD Griya Loka, Tangerang                              SHM   2200.0  ...
# 122      Pagedangan, Tangerang                              SHM   2200.0  ...
# 123           Poris, Tangerang                              SHM   3500.0  ...
#
#     Unnamed: 16  Unnamed: 17 Unnamed: 18 Unnamed: 19  Unnamed: 20  \
# 119         NaN          NaN         NaN         NaN          NaN
# 120         NaN          NaN         NaN         NaN          NaN
# 121         NaN          NaN         NaN         NaN          NaN
# 122         NaN          NaN         NaN         NaN          NaN
# 123         NaN          NaN         NaN         NaN          NaN
#
#      Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 119          NaN          NaN          NaN          NaN          NaN
# 120          NaN          NaN          NaN          NaN          NaN
# 121          NaN          NaN          NaN          NaN          NaN
# 122          NaN          NaN          NaN          NaN          NaN
# 123          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 26 columns]

# %%
dfX.drop(dfX.index[107:993],inplace=True)
dfX.tail()
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport            lokasi  \
# 102  01-12-2021  180.0  220.0  5.0  3.0     NaN      NaN       Kota Bekasi
# 103  01-12-2021  140.0  250.0  3.0  2.0     NaN      NaN  Kabupaten Bekasi
# 104  01-12-2021   60.0   55.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi
# 105  01-12-2021   36.0   60.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi
# 106  01-12-2021   60.0   55.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi
#
#     sertifikat  listrik  ... Unnamed: 16  Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 102        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 103        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 104        SHM   1300.0  ...         NaN          NaN         NaN         NaN
# 105        SHM   1300.0  ...         NaN          NaN         NaN         NaN
# 106        SHM   1300.0  ...         NaN          NaN         NaN         NaN
#
#      Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 102          NaN          NaN          NaN          NaN          NaN
# 103          NaN          NaN          NaN          NaN          NaN
# 104          NaN          NaN          NaN          NaN          NaN
# 105          NaN          NaN          NaN          NaN          NaN
# 106          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 25
# 102          NaN
# 103          NaN
# 104          NaN
# 105          NaN
# 106          NaN
#
# [5 rows x 26 columns]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas import read_csv
dfmerge
dfmerge.shape
dfmerge.info()

# %%
dfmerge = pd.concat([dfJ,dfB,dfD,dfT,dfX])
dfmerge
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport            lokasi  \
# 0    06-12-2021  202.0  198.0  8.0  3.0     NaN      NaN     Jakarta Pusat
# 1    02-12-2021   30.0   55.0  2.0  1.0     NaN      1.0     Jakarta Pusat
# 2    06-12-2021   19.0   35.0  2.0  1.0     NaN      NaN     Jakarta Pusat
# 3    06-12-2021   33.0   42.0  2.0  2.0     NaN      1.0     Jakarta Pusat
# 4    06-12-2021   30.0   55.0  2.0  2.0     NaN      1.0     Jakarta Pusat
# ..          ...    ...    ...  ...  ...     ...      ...               ...
# 102  01-12-2021  180.0  220.0  5.0  3.0     NaN      NaN       Kota Bekasi
# 103  01-12-2021  140.0  250.0  3.0  2.0     NaN      NaN  Kabupaten Bekasi
# 104  01-12-2021   60.0   55.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi
# 105  01-12-2021   36.0   60.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi
# 106  01-12-2021   60.0   55.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi
#
#     sertifikat  listrik  ... Unnamed: 16  Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0          SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 1          SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 2          SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 3          SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 4          SHM   2200.0  ...         NaN          NaN         NaN         NaN
# ..         ...      ...  ...         ...          ...         ...         ...
# 102        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 103        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 104        SHM   1300.0  ...         NaN          NaN         NaN         NaN
# 105        SHM   1300.0  ...         NaN          NaN         NaN         NaN
# 106        SHM   1300.0  ...         NaN          NaN         NaN         NaN
#
#      Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 102          NaN          NaN          NaN          NaN          NaN
# 103          NaN          NaN          NaN          NaN          NaN
# 104          NaN          NaN          NaN          NaN          NaN
# 105          NaN          NaN          NaN          NaN          NaN
# 106          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 25
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 102          NaN
# 103          NaN
# 104          NaN
# 105          NaN
# 106          NaN
#
# [663 rows x 26 columns]

# %%
dfmerge.drop(dfmerge.columns[14:26], axis=1, inplace=True)
print(dfmerge)
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport            lokasi  \
# 0    06-12-2021  202.0  198.0  8.0  3.0     NaN      NaN     Jakarta Pusat
# 1    02-12-2021   30.0   55.0  2.0  1.0     NaN      1.0     Jakarta Pusat
# 2    06-12-2021   19.0   35.0  2.0  1.0     NaN      NaN     Jakarta Pusat
# 3    06-12-2021   33.0   42.0  2.0  2.0     NaN      1.0     Jakarta Pusat
# 4    06-12-2021   30.0   55.0  2.0  2.0     NaN      1.0     Jakarta Pusat
# ..          ...    ...    ...  ...  ...     ...      ...               ...
# 102  01-12-2021  180.0  220.0  5.0  3.0     NaN      NaN       Kota Bekasi
# 103  01-12-2021  140.0  250.0  3.0  2.0     NaN      NaN  Kabupaten Bekasi
# 104  01-12-2021   60.0   55.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi
# 105  01-12-2021   36.0   60.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi
# 106  01-12-2021   60.0   55.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi
#
#     sertifikat  listrik    hadap         harga  \
# 0          SHM   2200.0      NaN  4.500000e+09
# 1          SHM   2200.0      NaN  1.100000e+09
# 2          SHM   2200.0      NaN  3.950000e+08
# 3          SHM   2200.0      NaN  8.350000e+08
# 4          SHM   2200.0      NaN  1.100000e+09
# ..         ...      ...      ...           ...
# 102        SHM   2200.0      NaN  1.600000e+09
# 103        SHM   2200.0  Selatan  8.500000e+08
# 104        SHM   1300.0      NaN  2.500000e+08
# 105        SHM   1300.0    Timur  3.000000e+08
# 106        SHM   1300.0      NaN  2.500000e+08
#
#                                                    URL  \
# 0    https://www.rumah.com/listing-properti/dijual-...
# 1    https://www.rumah.com/listing-properti/dijual-...
# 2    https://www.rumah.com/listing-properti/dijual-...
# 3    https://www.rumah.com/listing-properti/dijual-...
# 4    https://www.rumah.com/listing-properti/dijual-...
# ..                                                 ...
# 102  https://www.rumah123.com/properti/bekasi/hos92...
# 103  https://www.rumah123.com/properti/bekasi/hos92...
# 104  https://www.rumah123.com/properti/bekasi/hos92...
# 105  https://www.rumah123.com/properti/bekasi/hos92...
# 106  https://www.rumah123.com/properti/bekasi/hos92...
#
#                                              deskripsi
# 0    Dekat Cikini Salemba Taman Isamail Marzuki Kam...
# 1    Mengusung konsep minimalis, dan didukung denga...
# 2    Dekat dengan Mall Atrium Senen, dekat dengan a...
# 3    Berlokasi sangat strategis, sangat dekat ke Tu...
# 4    Bisa request ubah tata ruang, beli 2 unit mend...
# ..                                                 ...
# 102  Akses pintu tol Bekasibarat; Dekat Mall Summar...
# 103  DIJUAL RUMAH, Taman Kebalen bekasi cluster, Ju...
# 104  Di jual Rumah Lelang Bank Pondok Ungu Permai, ...
# 105  Lokasi Super Strategis, Selangkah menuju Kota ...
# 106  RCG/20/V/010 MP/LB/THM/010 Di jual Rumah Lelan...
#
# [663 rows x 14 columns]

# %%
dfmerge.duplicated().sum()
# Out:
# 2

# %%
dfmerge.describe()
# Out:
#                 LB          KT          KM      garasi     carport  \
# count   660.000000  660.000000  659.000000  332.000000  547.000000
# mean    150.977273    3.148485    2.294385    0.828313    1.491773
# std     199.780489    1.386828    1.368829    1.292804    1.083267
# min      15.000000    1.000000    1.000000    0.000000    0.000000
# 25%      49.750000    2.000000    1.000000    0.000000    1.000000
# 50%      82.000000    3.000000    2.000000    0.000000    1.000000
# 75%     172.000000    4.000000    3.000000    1.000000    2.000000
# max    2500.000000   10.000000   10.000000   10.000000   10.000000
#
#             listrik         harga
# count    625.000000  6.600000e+02
# mean    3057.920000  2.183642e+09
# std     4782.215869  7.613401e+09
# min      900.000000  4.100000e+01
# 25%     1300.000000  1.950000e+03
# 50%     2200.000000  4.530000e+08
# 75%     2200.000000  1.326000e+09
# max    66000.000000  1.050000e+11

# %%
#melihat adanya outlier
p = sns.boxplot(x="LT", y="harga", data=dfmerge)
#mengecek apakah terdapat duplikasi data
print(dfmerge.shape)
dfmerge.duplicated().sum()
# Out:
# (663, 14)
# 2

# %%
#menghapus data duplikat
dfmerge.drop_duplicates(inplace=True)
print(dfmerge.duplicated().sum())
print(dfmerge.shape)
# Out:
# 0
# (661, 14)

# %%
#mengecek jumlah missing value
print(dfmerge.isnull().sum())
# Out:
# created_at      1
# LT              1
# LB              1
# KT              1
# KM              2
# garasi        329
# carport       114
# lokasi          1
# sertifikat      6
# listrik        36
# hadap         450
# harga           1
# URL             1
# deskripsi      10
# dtype: int64

# %%
#untuk mengetahui harga terbesar terdapat di lokasi mana
besar_harga=dfmerge.groupby('lokasi')['harga'].sum().reset_index()
besar_harga
# Out:
#                        lokasi         harga
# 0      ALAM SUTERA, TANGERANG  4.150000e+03
# 1    BANJAR WIJAYA, TANGERANG  3.900000e+03
# 2            BENDA, TANGERANG  2.900000e+03
# 3   BSD BUKIT GOLF, TANGERANG  1.000000e+05
# 4         BSD CITY, TANGERANG  9.116000e+04
# ..                        ...           ...
# 81                  Sukmajaya  1.476700e+04
# 82                Tajurhalang  1.250634e+09
# 83               Tanah Sareal  5.280096e+09
# 84                      Tapos  7.509000e+03
# 85                      Tenjo  1.680000e+08
#
# [86 rows x 2 columns]
